# %%
print("MY RESUME")
print("\nPlease fill in your correct details below")
print("\nRead the instructions given before answering\n")

#Personal or Basic info section
print("PERSONAL INFORMATION")
lname = input("Last name:  ")
fname = input("First name:  ")
Tel = input("Phone number:  ")
location = input("Location:  ")
email = input("E-mail:  ") 

import pandas as pd
import numpy as np
basic = {'Last name':[lname], 'First name':[fname], 'Phone number':[Tel], 'Location':[location], 'Email':[email]}
p_info = pd.DataFrame(basic)
p_info.to_csv(lname+'_personal_information.csv')
p_info

#Work Experience section
print("\n\nWORK EXPERIENCE")
wrk = input("Have you had any work experience: Yes/No\n")
if wrk == "yes" or "Yes":
    job = list(input("Enter position, name of organisation, year spent\n(use fullstop '.' to separate the jobs if more than one):\n").split(". "))
    yr_exp = input("Total Years of Experience:\n")
    summary = input("Write your work summary here:\n")
    tp_ach = list(input("\nTop Achievements:(optional)\n(use a comma ',' to separate your achievements):\n").split(", "))
    objective = input("Write your work objective here:\n")
elif wrk == "no" or "No":
	objective = input("Write your work objective here:\n")
else:
        objective = input("\nWrite your work objective here:\n")


work = {'Position':[job], 'Years of Experience':[yr_exp], 'Role summary':[summary], 'Top Achievements':[tp_ach], 'Objective':[objective]}
work_exp = pd.DataFrame(work)
work_exp.to_csv(lname+'_work_experience.csv')


        
print("\n\nSKILL")
skills = list(input("Skills: (use ',' to seperate the skill from another):\n").split(", "))

print("\n\nREFERENCE")
ref = list(input("Enter reference(distinguish reference with a fullstop '.')\n").split(". "))

skill = {'Skills':[skills], 'Ref':[ref]}
aq_skill = pd.DataFrame(skill)
aq_skill.to_csv(lname+'_skills.csv')


print("\n\n", fname.upper()+"'S", "RESUME")
print("\nPROFILE\n")
print("NAME:                     ", fname, lname)
print("Phone number:             ", Tel)
print("E-mail:                   ", email)
print("Location:                 ", location)
print("\n-----------------------------------------------------\n")
#print("EDUCATION BACKGROUND\n")
#for i in range(0,len(ED),5):
 #       print("\nStudied:    ", ED[i+0], ED[i+1])
  #      print("At:         ", ED[i+2])
   #     print("From:       ", ED[i+3], "--", ED[i+4])
#if ach:
#	print("\nAcademic Achievements")
#	for i in ach:
#		print("->",i)
#else:
 #       print(None)
#print("\n-----------------------------------------------------\n")
print("WORK EXPERIENCE\n")
if wrk == "yes" and "Yes": #summary:
        for i in job:
                a = i.split(', ')
                print("Worked as a(n)", a[0], "in", a[1], "for", a[2])
        print("Years of experience:", yr_exp)
        if tp_ach:
                print("\nTop Achievements\n")
                for i in tp_ach:
                        print("->",i)
        else:
                print(None)
        print("\n-----------------------------------------------------\n")
        print("SKILLS\n")
        for i in skills:
                print("->",i)
        print("\n-----------------------------------------------------\n")
        print("\nRESUME SUMMARY\n", summary)
else:
        print("No work experience.")
        print("\n\n-----------------------------------------------------\n")
        print("SKILLS\n")
        for i in skills:
                print("->",i)
        print("\n-----------------------------------------------------\n")
        print("\nRESUME OBJECTIVE\n", objective)
print("\n-----------------------------------------------------\n")
print("REFERENCE\n")
for i in ref:
        print("*", i)
# Out:
# MY RESUME
#
# Please fill in your correct details below
#
# Read the instructions given before answering
#
# PERSONAL INFORMATION
# Last name:  Statesman
# First name:  Oyehan Adeyinka
# Phone number:  0582556152
# Location:  Dhahran
# E-mail:  adeyinka.statesman@gmail.com
#
#
# WORK EXPERIENCE
# Have you had any work experience: Yes/No
# Yes
# Enter position, name of organisation, year spent
# (use fullstop '.' to separate the jobs if more than one):
# Research assistant, UPM, 5 years
# Total Years of Experience:
# 5 years
# Write your work summary here:
# Perform research activities
#
# Top Achievements:(optional)
# (use a comma ',' to separate your achievements):
# Published research that formed basis of a new procedure in water treatment
# Write your work objective here:
# To be a versatile Python programmer
#
#
# SKILL
# Skills: (use ',' to seperate the skill from another):
# Basic level of python
#
#
# REFERENCE
# Enter reference(distinguish reference with a fullstop '.')
# ...
